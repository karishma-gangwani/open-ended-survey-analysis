# %%
##Import cvs file and pandas

import pandas as pd
import numpy as np
xls = pd.ExcelFile('Detractor Relational Survey Data.xlsx')
df = pd.read_excel(xls)
df = df.copy()

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
df.head()
# Out:
#     CGID              Parent_Account First_Name    Last_Name             Name  \
# 0  85900                INEOS CANADA        Rob       Gaudry       Rob Gaudry
# 1  85937  PPG ACCHITECTURAL COATINGS        Vic  Ramcharitar  Vic Ramcharitar
# 2  86109               NEXANS CANADA     Roland      Barkley   Roland barkley
# 3  86119                         NaN     Benoit     Langlois  Benoit Langlois
# 4  86365        ENTREPRISES BARRETTE      Denis    Thibeault  Denis Thibeault
#
#            Contact_ID               Title Province Language Job_Level  ...  \
# 0  0030B00001siZ5aQAE                 NaN       AB       EN         U  ...
# 1  0030B00001siv01QAA  Operations Manager       AB       EN         B  ...
# 2  0030B00001tTSiEQAW                 NaN       QC       FR         U  ...
# 3  0030B00001tTYKoQAO   Directeur général       QC       FR         B  ...
# 4  0030B00001tW3jmQAC            ACHETEUR       QC       FR         C  ...
#
# ...

# %%
df.shape
# Out:
# (188, 21)

# %%
df.columns
# Out:
# Index(['CGID', 'Parent_Account', 'First_Name', 'Last_Name', 'Name',
#        'Contact_ID', 'Title', 'Province', 'Language', 'Job_Level', 'Phone',
#        'Mobile', 'Email', 'Account_Name', 'Industry', 'Survey_Type',
#        'NetPromoterScore', 'Survey_Completed_Date', 'Email_Sent_Date',
#        'Reasons_List', 'Comment_Translation'],
#       dtype='object')

# %%
#checking for missing values
df.isnull().sum()
df.isna().sum()
# Out:
# CGID                       0
# Parent_Account           108
# First_Name                 0
# Last_Name                  0
# Name                       0
# Contact_ID                 0
# Title                     78
# Province                  65
# Language                   0
# Job_Level                  0
# Phone                     13
# Mobile                   112
# Email                      0
# Account_Name               0
# Industry                  24
# Survey_Type                0
# NetPromoterScore           0
# Survey_Completed_Date      0
# Email_Sent_Date            0
# Reasons_List              18
# Comment_Translation      116
# dtype: int64

# %%
#Replace missing values with a string value
df = df.fillna("NA")

# %%
#change dataframe to lowercase letters
df = df.applymap(lambda s:s.lower() if type(s) == str else s)

# %%
df['Reasons_List 17000'] = None
df['Reasons_List 19200'] = None
df['Reasons_List 19120'] = None
df['Reasons_List 19000'] = None
df['Reasons_List 15000'] = None
df['Reasons_List 19180'] = None
df['Reasons_List 19160'] = None
df['Reasons_List 13000'] = None
df['Reasons_List 11000'] = None
df['Reasons_List 19140'] = None
df['Reasons_List 19020'] = None

# %%
'Reasons_List 17000', 'Reasons_List 19200', 'Reasons_List 19120', 'Reasons_List 19000', 'Reasons_List 15000', 
'Reasons_List 19180', 'Reasons_List 19160', 'Reasons_List 13000','Reasons_List 11000', 'Reasons_List 19140', 
'Reasons_List 19020'
# Out:
# 'Reasons_List 19020'

# %%
df.columns
# Out:
# Index(['CGID', 'Parent_Account', 'First_Name', 'Last_Name', 'Name',
#        'Contact_ID', 'Title', 'Province', 'Language', 'Job_Level', 'Phone',
#        'Mobile', 'Email', 'Account_Name', 'Industry', 'Survey_Type',
#        'NetPromoterScore', 'Survey_Completed_Date', 'Email_Sent_Date',
#        'Reasons_List', 'Comment_Translation', 'Reasons_List 17000',
#        'Reasons_List 19200', 'Reasons_List 19120', 'Reasons_List 19000',
#        'Reasons_List 15000', 'Reasons_List 19180', 'Reasons_List 19160',
#        'Reasons_List 13000', 'Reasons_List 11000', 'Reasons_List 19140',
#        'Reasons_List 19020'],
#       dtype='object')

# %%
df.head()
# Out:
#     CGID              Parent_Account First_Name    Last_Name             Name  \
# 0  85900                ineos canada        rob       gaudry       rob gaudry
# 1  85937  ppg acchitectural coatings        vic  ramcharitar  vic ramcharitar
# 2  86109               nexans canada     roland      barkley   roland barkley
# 3  86119                          na     benoit     langlois  benoit langlois
# 4  86365        entreprises barrette      denis    thibeault  denis thibeault
#
#            Contact_ID               Title Province Language Job_Level  ...  \
# 0  0030b00001siz5aqae                  na       ab       en         u  ...
# 1  0030b00001siv01qaa  operations manager       ab       en         b  ...
# 2  0030b00001ttsieqaw                  na       qc       fr         u  ...
# 3  0030b00001ttykoqao   directeur général       qc       fr         b  ...
# 4  0030b00001tw3jmqac            acheteur       qc       fr         c  ...
#
# ...

# %%
#change dataframe to lowercase letters
df = df.applymap(lambda s:s.lower() if type(s) == str else s)

# %%
#add values from 3-First into Pareto_3First based on defined conditions
condition_1 = ['quote']
condition_2 = ['quickly']
condition_3 = ['quality']
condition_4 = ['invoicing']
condition_5 = ['competitive',]
condition_6 =['product']
condition_7= ['follow-up']
condition_8 = ['knowledgeable']
condition_9 = ['technical']
condition_10 = ['performance']
condition_11 = ['variety']

# %%
#Adding binary values in new columns
def checkWords(word: str):
    for ch in condition_1:
        if ch in word:
            return 1
    return 0
df['Reasons_List 17000'] = df['Reasons_List'].apply(checkWords)

#Adding binary values in new columns
def checkWords(word: str):
    for ch in condition_2:
        if ch in word:
            return 1
    return 0
df['Reasons_List 19200'] = df['Reasons_List'].apply(checkWords)

#Adding binary values in new columns
def checkWords(word: str):
    for ch in condition_3:
        if ch in word:
            return 1
    return 0
df['Reasons_List 19120'] = df['Reasons_List'].apply(checkWords)

#Adding binary values in new columns
def checkWords(word: str):
    for ch in condition_4:
        if ch in word:
            return 1
    return 0
df['Reasons_List 19000'] = df['Reasons_List'].apply(checkWords)

#Adding binary values in new columns
def checkWords(word: str):
    for ch in condition_5:
        if ch in word:
            return 1
    return 0
df['Reasons_List 15000'] = df['Reasons_List'].apply(checkWords)

#Adding binary values in new columns
def checkWords(word: str):
    for ch in condition_6:
        if ch in word:
            return 1
    return 0
df['Reasons_List 19180'] = df['Reasons_List'].apply(checkWords)

#Adding binary values in new columns
def checkWords(word: str):
    for ch in condition_7:
        if ch in word:
            return 1
    return 0
df['Reasons_List 19160'] = df['Reasons_List'].apply(checkWords)

#Adding binary values in new columns
def checkWords(word: str):
    for ch in condition_8:
        if ch in word:
            return 1
    return 0
df['Reasons_List 13000'] = df['Reasons_List'].apply(checkWords)

#Adding binary values in new columns
def checkWords(word: str):
    for ch in condition_9:
        if ch in word:
            return 1
    return 0
df['Reasons_List 11000'] = df['Reasons_List'].apply(checkWords)

#Adding binary values in new columns
def checkWords(word: str):
    for ch in condition_10:
        if ch in word:
            return 1
    return 0
df['Reasons_List 19140'] = df['Reasons_List'].apply(checkWords)

#Adding binary values in new columns
def checkWords(word: str):
    for ch in condition_11:
        if ch in word:
            return 1
    return 0
df['Reasons_List 19020'] = df['Reasons_List'].apply(checkWords)

print(df)
# Out:
#        CGID                 Parent_Account    First_Name      Last_Name  \
# 0     85900                   ineos canada           rob         gaudry
# 1     85937     ppg acchitectural coatings           vic    ramcharitar
# 2     86109                  nexans canada        roland        barkley
# 3     86119                             na        benoit       langlois
# 4     86365           entreprises barrette         denis      thibeault
# 5     86408              damco ditribution          neil        simicak
# 6     86451                             na      giocondo           niro
# 7     86689                             na          mike        crozier
# 8     86714                             na           léo       lapointe
# 9     87287                             na        darrel       fingland
# 10    87317                             na       stephan      humphreys
# 11    87458                bridgeview manu         kevin         hruska
# ...

# %%
df.to_excel('Wajax-KG.xlsx')
